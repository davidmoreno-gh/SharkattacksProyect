# %%
pip install pandas xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import pandas as pd

df_sharkattack= pd.read_excel('https://www.sharkattackfile.net/spreadsheets/GSAF5.xls')
df_sharkattack.head()
# Out:
#           Date    Year        Type    Country              State  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1  04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2  02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3  25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4  14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
#
#                            Location  Activity                 Name Sex  Age  \
# 0                     Bargara Beach  Swimming       Brooklyn Sauer   F   13
# 1                Old Man's, Waikiki   Surfing        Matthew White   M  NaN
# 2                    Rainbows, Oahu  Swimming                  NaN   F   11
# 3        Sandlnd Island, Jurian Bay       NaN               female   F   46
# 4  Vaitarna River, Palghar District   Fishing  Vicky Suresh Govari   M   32
#
#                                      Injury Unnamed: 11   Time  \
# ...

# %% [markdown]
# Inicio del proceso de limpieza:
# Quitamos las filas (variables) y columnas (datos segun fecha) que no vamos a necesitar para el análisis de nuestro proyecto.
# Al tratarse de un proyecto de venta de pulseras anti ataque de tiburones, no consideramos necesario tener datos de siglos pasados,
# necesitamos tener una tendencia de los datos para poder analizarlos, por ello y por tener un considerable numero de datos
# hemos decidido quedarnos con los datos a partir de la decada de los 60, podriamos quedarnos con los datos desde 1900, pero no aportan un
# gran valor al analisis y además, están bastante incompletos.

# %%
#miro el numero de filas y columnas totales

df_sharkattack.shape #el resultado es 6969, 23 siendo 0 el indice habria 6968 filas y 22 columnas
# reviso que datos hay en la ultima fila dado que no aparecen en el excel
# Out:
# (6969, 23)

# %%
df_sharkattack.tail(1) #esto me hace comprobar que hay filas completamente nulas y por eso no aparecen en el excel y a su vez
                        # somos conscientes de que si no se comprobase seguiriamos teniendo valores nulos que no aportan ningun valor en el data frame
# Out:
#      Date  Year Type Country State Location Activity Name  Sex  Age Injury  \
# 6968  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
#
#      Unnamed: 11 Time Species  Source  pdf  \
# 6968         NaN  NaN      NaN    NaN  NaN
#
#                                            href formula href Case Number  \
# 6968  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN         NaN
#
#      Case Number.1  original order Unnamed: 21 Unnamed: 22
# 6968           NaN             NaN         NaN         NaN

# %%
# Crear una lista de índices desde fila 4402 hasta el numero total de filas (incluyendo esa fila)
filas_a_eliminar = list(range(4402, 6969))

# %%
#Utilizamos la funcion drop para poder quitar las filas que no necesitamos a traves de la variable anterior

df_sharkattack = df_sharkattack.drop(filas_a_eliminar)

# %%
# Compruebo que haya variado el numero de filas a 4402 (hay que tener en cuenta que el indice empieza por 0)

df_sharkattack.shape #comprobado todo está correcto
# Out:
# (4402, 23)

# %% [markdown]
# A continuación, vamos a quitar las columnas que no son necesarias para nuestro análisis:
#
#     En primer lugar, vamos a comprobar y quitar las columnas que están compuestas de valores nulos en la gran mayoría.
#     En segundo lugar, vamos a quitar las columnas de las variables type,name,injury,time,source que no necesitamos para nuestro analisis al tener datos que no vemos que influya en las ventas

# %%
#df_sharkattack.info()
columnas_nulas_completas = df_sharkattack.columns[df_sharkattack.isnull().all()]
columnas_nulas_completas # con ella vemos que solo hay una columna sin ningun dato unnamed 22 que está en la fila 22

# Count the number of null values in each column
df_sharkattack.isna().sum()

#las columnas unnamed_21 y  unnamed_22 tienen todos o casi todos los valores nulos 4402

 # las columnas pdf, href_formula, href, case_number, case_number_1, original_order no 
 # tienen tantos valores nulos pero no las vamos a necesitar para nuestro analisis por lo tanto las vamos a eliminar tambien
# Out:
# date                 0
# year                 1
# type                14
# country             11
# state              209
# location           250
# activity           282
# name                96
# sex                299
# age               1262
# injury              18
# unnamed_11         327
# time              1607
# species           1598
# source              14
# pdf                142
# href_formula       147
# href               145
# case_number        143
# case_number_1      144
# original_order     142
# unnamed_21        4401
# unnamed_22        4402
# dtype: int64

# %%
df_sharkattack.columns = df_sharkattack.columns.str.lower().str.replace(" ","_").str.replace(".","_").str.replace(":","").str.strip()
df_sharkattack = df_sharkattack.rename(columns={"species_" : "species"})
df_sharkattack.info(24)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4402 entries, 0 to 4401
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4402 non-null   object
#  1   year            4401 non-null   float64
#  2   type            4388 non-null   object
#  3   country         4391 non-null   object
#  4   state           4193 non-null   object
#  5   location        4152 non-null   object
#  6   activity        4120 non-null   object
#  7   name            4306 non-null   object
#  8   sex             4103 non-null   object
#  9   age             3140 non-null   object
#  10  injury          4384 non-null   object
#  11  unnamed_11      4075 non-null   object
#  12  time            2795 non-null   object
#  13  species         2804 non-null   object
#  14  source          4388 non-null   object
#  15  pdf             4260 non-null   object
#  16  href_formula    4255 non-null   object
# ...

# %%
df_sharkattack.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'state', 'location', 'activity',
#        'name', 'sex', 'age', 'injury', 'unnamed_11', 'time', 'species',
#        'source', 'pdf', 'href_formula', 'href', 'case_number', 'case_number_1',
#        'original_order', 'unnamed_21', 'unnamed_22'],
#       dtype='object')

# %%
columns_failed = ['type','name','injury','time','source','pdf', 'href_formula', 'href', 'case_number', 'case_number_1', 'original_order','unnamed_21','unnamed_22']

# %%
df_sharkattack = df_sharkattack.drop(columns = columns_failed)

# %%
df_sharkattack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4402 entries, 0 to 4401
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        4402 non-null   object
#  1   year        4401 non-null   float64
#  2   country     4391 non-null   object
#  3   state       4193 non-null   object
#  4   location    4152 non-null   object
#  5   activity    4120 non-null   object
#  6   sex         4103 non-null   object
#  7   age         3140 non-null   object
#  8   unnamed_11  4075 non-null   object
#  9   species     2804 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 344.0+ KB

# %%
# cambio el nombre de la columna unnamed_11 a un nombre significativo

df_sharkattack = df_sharkattack.rename(columns={"unnamed_11" : "death"})

# %%
df_sharkattack
# Out:
#              date    year       country              state  \
# 0     15 Mar 2024  2024.0     AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0           USA             Hawaii
# 2     02 Mar-2024  2024.0           USA             Hawaii
# 3     25 Feb-2024  2024.0     AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0         INDIA        Maharashtra
# ...           ...     ...           ...                ...
# 4397  11-Jan-1963  1963.0  SOUTH AFRICA      KwaZulu-Natal
# 4398  06-Jan-1963  1963.0  SOUTH AFRICA      KwaZulu-Natal
# 4399  04-Jan-1963  1963.0     AUSTRALIA    South Australia
# 4400     Jan-1963  1963.0    MOZAMBIQUE                NaN
# 4401   Early 1963  1963.0          FIJI          Vita Levu
#
#                                               location  \
# 0                                        Bargara Beach
# 1                                   Old Man's, Waikiki
# 2                                       Rainbows, Oahu
# ...
